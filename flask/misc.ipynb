# %%
import pandas as pd
import numpy as np

# %%
def random_dates(start, end, n=10000):
    start_u = start.value//10**9
    end_u = end.value//10**9
    
    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
start = pd.to_datetime('2009-01-01')
end = pd.to_datetime('2021-01-01')

da = random_dates(start, end)

# %%
da
# Out:
# DatetimeIndex(['2016-09-17 11:21:46', '2017-07-23 05:43:00',
#                '2018-04-28 19:05:49', '2011-10-12 00:13:00',
#                '2009-07-20 06:35:38', '2015-06-16 01:42:52',
#                '2018-02-28 22:12:25', '2019-06-07 01:39:48',
#                '2019-11-10 14:09:02', '2014-05-06 20:52:11',
#                ...
#                '2013-12-06 17:30:03', '2011-01-25 17:44:51',
#                '2020-05-25 07:15:59', '2011-06-25 15:27:59',
#                '2015-06-08 00:44:40', '2011-10-02 15:36:22',
#                '2013-06-26 05:17:12', '2012-12-18 21:28:27',
#                '2009-12-14 19:38:22', '2009-03-15 19:15:28'],
#               dtype='datetime64[ns]', length=10000, freq=None)

# %%
int = np.random.randn(10000)

# %%
int_up =abs(int)

# %%
int_up
# Out:
# array([1.01094412, 0.80765842, 1.33112551, ..., 0.4622251 , 0.71292112,
#        0.5562069 ])

# %%
pd.DataFrame({'a':da, 'b':int_up})
# Out:
#                        a         b
# 0    2016-09-17 11:21:46  1.010944
# 1    2017-07-23 05:43:00  0.807658
# 2    2018-04-28 19:05:49  1.331126
# 3    2011-10-12 00:13:00  0.503601
# 4    2009-07-20 06:35:38  0.387755
# ...                  ...       ...
# 9995 2011-10-02 15:36:22  1.352303
# 9996 2013-06-26 05:17:12  1.298713
# 9997 2012-12-18 21:28:27  0.462225
# 9998 2009-12-14 19:38:22  0.712921
# 9999 2009-03-15 19:15:28  0.556207
#
# [10000 rows x 2 columns]

# %%
int_lo = np.random.randint(0,20,10000)

# %%
int_hi = np.random.randint(20,30,10000)

# %%
df = pd.DataFrame({"A":int_lo, "B":int_hi, "C": int_up, "D": da, "E": te})

# %%
df.to_csv("./mm.csv")

# %%
np.random.randint(1,6)
# Out:
# 5

# %%
te
# Out:
# []

# %%
te.append(5)

# %%
te = []

# %%
b = ['A',"G","R","T","S","C","M","R"]

# %%
for i in range(10000):
    n = np.random.randint(1,6)
    te.append(b[n])

# %%
df.
# Out:
# ['R',
#  'R',
#  'G',
#  'R',
#  'R',
#  'G',
#  'C',
#  'S',
#  'S',
#  'S',
#  'S',
#  'C',
#  'R',
#  'R',
#  'S',
#  'R',
#  'S',
#  'T',
#  'C',
#  'G',
#  'T',
#  'C',
#  'C',
#  'R',
#  'G',
#  'C',
#  'R',
#  'T',
#  'C',
#  'S',
#  'S',
#  'T',
#  'T',
#  'S',
#  'G',
#  'C',
#  'T',
#  'S',
#  'T',
#  'R',
#  'R',
#  'C',
#  'T',
#  'C',
#  'R',
#  'S',
#  'C',
#  'R',
#  'C',
#  'T',
#  'S',
#  'S',
#  'T',
#  'C',
#  'S',
#  'C',
#  'C',
#  'S',
#  'T',
#  'R',
#  'C',
#  'S',
#  'C',
#  'S',
#  'T',
#  'R',
#  'C',
#  'G',
#  'R',
#  'T',
#  'T',
#  'G',
#  'R',
#  'G',
#  'G',
#  'C',
#  'T',
#  'R',
#  'C',
#  'G',
#  'S',
#  'T',
#  'S',
#  'R',
#  'R',
#  'S',
#  'G',
#  'R',
#  'G',
#  'S',
#  'T',
#  'T',
#  'S',
#  'R',
#  'S',
#  'G',
#  'S',
#  'T',
#  'G',
#  'S',
#  'C',
#  'C',
#  'R',
#  'R',
#  'R',
#  'R',
#  'C',
#  'T',
#  'G',
#  'G',
#  'C',
#  'G',
#  'G',
#  'R',
#  'R',
#  'G',
#  'C',
#  'C',
#  'C',
#  'C',
#  'S',
#  'C',
#  'S',
#  'G',
#  'T',
# ...

# %%
df
# Out:
#        A   B         C                   D  E
# 0     12  22  1.010944 2016-09-17 11:21:46  R
# 1      0  23  0.807658 2017-07-23 05:43:00  R
# 2     12  26  1.331126 2018-04-28 19:05:49  G
# 3     13  27  0.503601 2011-10-12 00:13:00  R
# 4     19  28  0.387755 2009-07-20 06:35:38  R
# ...   ..  ..       ...                 ... ..
# 9995   7  20  1.352303 2011-10-02 15:36:22  G
# 9996   9  22  1.298713 2013-06-26 05:17:12  R
# 9997  16  25  0.462225 2012-12-18 21:28:27  G
# 9998   0  26  0.712921 2009-12-14 19:38:22  T
# 9999   4  22  0.556207 2009-03-15 19:15:28  C
#
# [10000 rows x 5 columns]
